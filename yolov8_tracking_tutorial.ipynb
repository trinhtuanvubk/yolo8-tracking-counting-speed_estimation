# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/mikel-brostrom/yolov8_tracking.git  # clone repo
# %cd /content/yolov8_tracking
# %pip install -r requirements.txt  # install dependencies
# %pip install thop                  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.1+cu118 (CPU)

# %% [markdown]
# # Download data
#
# Get test video from repo and extract the first 2 seconds of it

# %%
# %cd /content/yolov8_tracking

# get the test video from the repo
# !wget -nc https://github.com/mikel-brostrom/yolov8_tracking/releases/download/v.2.0/test.avi
# extract 3 seconds worth of video frames of it
# !yes | ffmpeg -ss 00:00:00 -i test.avi -t 00:00:01 -vf fps=30 out.avi
# Out:
# /content/yolov8_tracking
# File ‘test.avi’ already there; not retrieving.
#
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, matroska,webm, from 'test.avi':
#   Metadata:
#     COMPATIBLE_BRANDS: isomiso2mp41
#     MAJOR_BRAND     : isom
#     MINOR_VERSION   : 512
#     ENCODER         : Lavf57.83.100
#   Duration: 00:00:35.00, start: 0.000000, bitrate: 1164 kb/s
#     Stream #0:0: Video: vp9 (Profile 0), yuv420p(tv, progressive), 960x540, SAR 1:1 DAR 16:9, 30 fps, 30 tbr, 1k tbn, 1k tbc (default)
#     Metadata:
#       HANDLER_NAME    : VideoHandler
#       ENCODER         : Lavc57.107.100 libvpx-vp9
#       DURATION        : 00:00:35.000000000
# File 'out.avi' already exists. Overwrite ? [y/N] Stream mapping:
#   Stream #0:0 -> #0:0 (vp9 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'out.avi':
#   Metadata:
#     COMPATIBLE_BRANDS: isomiso2mp41
#     MAJOR_BRAND     : isom
#     MINOR_VERSION   : 512
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 960x540 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       HANDLER_NAME    : VideoHandler
#       DURATION        : 00:00:35.000000000
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   30 fps=0.0 q=18.0 Lsize=     129kB time=00:00:01.00 bitrate=1055.1kbits/s speed=2.67x
# video:122kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.182988%

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# !python track.py --yolo-model weights/yolov8n.pt --reid-model osnet_x0_25_msmt17.pt --source out.avi --save
# Out:
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=osnet_x0_25_msmt17.pt, tracking_method=deepocsort, source=out.avi, imgsz=[640], conf=0.5, device=, show=False, save=True, classes=None, project=/content/yolov8_tracking/runs/track, name=exp, exists_ok=False, half=False, vid_stride=1
# weights/yolov8n.pt
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to weights/yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 59.4MB/s]
# Successfully loaded pretrained weights from "osnet_x0_25_msmt17.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# video 1/1 (1/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 266.1ms
# video 1/1 (2/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 283.7ms
# video 1/1 (3/30) /content/yolov8_tracking/out.avi: 384x640 13 persons, 1 car, 1 motorcycle, 673.5ms
# video 1/1 (4/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 268.9ms
# video 1/1 (5/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 258.4ms
# video 1/1 (6/30) /content/yolov8_tracking/out.avi: 384x640 13 persons, 1 car, 1 motorcycle, 259.0ms
# video 1/1 (7/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 249.0ms
# video 1/1 (8/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 217.7ms
# video 1/1 (9/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 174.9ms
# video 1/1 (10/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 172.9ms
# video 1/1 (11/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 179.0ms
# video 1/1 (12/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 173.6ms
# video 1/1 (13/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 187.7ms
# video 1/1 (14/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 173.1ms
# video 1/1 (15/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 177.4ms
# video 1/1 (16/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 173.9ms
# video 1/1 (17/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 170.8ms
# video 1/1 (18/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 192.0ms
# video 1/1 (19/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 172.9ms
# video 1/1 (20/30) /content/yolov8_tracking/out.avi: 384x640 8 persons, 1 car, 172.6ms
# video 1/1 (21/30) /content/yolov8_tracking/out.avi: 384x640 8 persons, 1 car, 176.7ms
# video 1/1 (22/30) /content/yolov8_tracking/out.avi: 384x640 8 persons, 1 car, 176.3ms
# video 1/1 (23/30) /content/yolov8_tracking/out.avi: 384x640 8 persons, 1 car, 183.0ms
# video 1/1 (24/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 178.6ms
# video 1/1 (25/30) /content/yolov8_tracking/out.avi: 384x640 7 persons, 1 car, 171.4ms
# video 1/1 (26/30) /content/yolov8_tracking/out.avi: 384x640 7 persons, 1 car, 172.8ms
# video 1/1 (27/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 173.9ms
# video 1/1 (28/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 173.4ms
# video 1/1 (29/30) /content/yolov8_tracking/out.avi: 384x640 7 persons, 1 car, 172.2ms
# video 1/1 (30/30) /content/yolov8_tracking/out.avi: 384x640 7 persons, 1 car, 174.6ms
# Speed: 5.1ms preprocess, 211.7ms inference, 1.7ms postprocess, 290.2ms tracking per image at shape (1, 3, 640, 640)
# Results saved to /content/yolov8_tracking/runs/track/exp4
# 31 labels saved to /content/yolov8_tracking/runs/track/exp4/labels

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# array-record                  0.2.0
# arviz                         0.15.1
# astropy                       5.2.2
# astunparse                    1.6.3
# attrs                         23.1.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# blosc2                        2.0.0
# bokeh                         2.4.3
# branca                        0.6.0
# build                         0.10.0
# CacheControl                  0.12.11
# cached-property               1.5.2
# cachetools                    5.3.0
# catalogue                     2.0.8
# certifi                       2022.12.7
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.12
# chex                          0.1.7
# click                         8.1.3
# cloudpickle                   2.2.1
# cmake                         3.25.2
# cmdstanpy                     1.1.0
# colorcet                      3.0.1
# colorlover                    0.3.0
# community                     1.0.0b1
# confection                    0.0.4
# cons                          0.4.5
# contextlib2                   0.6.0.post1
# contourpy                     1.0.7
# convertdate                   2.4.0
# cryptography                  40.0.2
# cufflinks                     0.17.3
# cvxopt                        1.3.0
# cvxpy                         1.3.1
# cycler                        0.11.0
# cymem                         2.0.7
# Cython                        0.29.34
# dask                          2022.12.1
# datascience                   0.17.6
# db-dtypes                     1.1.1
# dbus-python                   1.2.16
# debugpy                       1.6.6
# decorator                     4.4.2
# defusedxml                    0.7.1
# distributed                   2022.12.1
# dlib                          19.24.1
# dm-tree                       0.1.8
# docutils                      0.16
# dopamine-rl                   4.0.6
# duckdb                        0.7.1
# earthengine-api               0.1.350
# easydict                      1.10
# ecos                          2.0.12
# editdistance                  0.6.2
# en-core-web-sm                3.5.0
# entrypoints                   0.4
# ephem                         4.1.4
# et-xmlfile                    1.1.0
# etils                         1.2.0
# etuples                       0.3.8
# exceptiongroup                1.1.1
# fastai                        2.7.12
# fastcore                      1.5.29
# fastdownload                  0.0.7
# fastjsonschema                2.16.3
# fastprogress                  1.0.3
# fastrlock                     0.8.1
# filelock                      3.12.0
# filterpy                      1.4.5
# firebase-admin                5.3.0
# Flask                         2.2.4
# flatbuffers                   23.3.3
# flax                          0.6.9
# folium                        0.14.0
# fonttools                     4.39.3
# frozendict                    2.3.7
# fsspec                        2023.4.0
# future                        0.18.3
# gast                          0.4.0
# GDAL                          3.3.2
# gdown                         4.6.6
# gensim                        4.3.1
# geographiclib                 2.0
# geopy                         2.3.0
# gin-config                    0.5.0
# gitdb                         4.0.10
# GitPython                     3.1.31
# glob2                         0.7
# google                        2.0.3
# google-api-core               2.11.0
# google-api-python-client      2.84.0
# google-auth                   2.17.3
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          1.0.0
# google-cloud-bigquery         3.9.0
# google-cloud-bigquery-storage 2.19.1
# google-cloud-core             2.3.2
# google-cloud-datastore        2.15.1
# google-cloud-firestore        2.11.0
# google-cloud-language         2.9.1
# google-cloud-storage          2.8.0
# google-cloud-translate        3.11.1
# google-colab                  1.0.0
# google-crc32c                 1.5.0
# google-pasta                  0.2.0
# google-resumable-media        2.5.0
# googleapis-common-protos      1.59.0
# googledrivedownloader         0.4
# graphviz                      0.20.1
# greenlet                      2.0.2
# grpcio                        1.54.0
# grpcio-status                 1.48.2
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5netcdf                      1.1.0
# h5py                          3.8.0
# hijri-converter               2.3.1
# holidays                      0.23
# holoviews                     1.15.4
# html5lib                      1.1
# httpimport                    1.3.0
# httplib2                      0.21.0
# humanize                      4.6.0
# hyperopt                      0.2.7
# idna                          3.4
# imageio                       2.25.1
# imageio-ffmpeg                0.4.8
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# imgaug                        0.4.0
# importlib-resources           5.12.0
# imutils                       0.5.4
# inflect                       6.0.4
# iniconfig                     2.0.0
# intel-openmp                  2023.1.0
# ipykernel                     5.5.6
# ipython                       7.34.0
# ipython-genutils              0.2.0
# ipython-sql                   0.4.1
# ipywidgets                    7.7.1
# itsdangerous                  2.1.2
# jax                           0.4.8
# jaxlib                        0.4.7+cuda11.cudnn86
# jedi                          0.18.2
# jieba                         0.42.1
# Jinja2                        3.1.2
# joblib                        1.2.0
# jsonpickle                    3.0.1
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter_core                  5.3.0
# jupyter-server                1.24.0
# jupyterlab-pygments           0.2.2
# jupyterlab-widgets            3.0.7
# kaggle                        1.5.13
# keras                         2.12.0
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.3.1
# langcodes                     3.3.0
# lap                           0.4.0
# lazy_loader                   0.2
# libclang                      16.0.0
# librosa                       0.10.0.post2
# lightgbm                      3.3.5
# lit                           16.0.5
# llvmlite                      0.39.1
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.2
# Markdown                      3.4.3
# markdown-it-py                2.2.0
# MarkupSafe                    2.1.2
# matplotlib                    3.7.1
# matplotlib-inline             0.1.6
# matplotlib-venn               0.11.9
# mdurl                         0.1.2
# miniKanren                    1.0.3
# missingno                     0.5.2
# mistune                       0.8.4
# mizani                        0.8.1
# mkl                           2019.0
# ml-dtypes                     0.1.0
# mlxtend                       0.14.0
# more-itertools                9.1.0
# moviepy                       1.0.3
# mpmath                        1.3.0
# msgpack                       1.0.5
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.9
# music21                       8.1.0
# natsort                       8.3.1
# nbclient                      0.7.4
# nbconvert                     6.5.4
# nbformat                      5.8.0
# nest-asyncio                  1.5.6
# networkx                      3.1
# nibabel                       3.0.2
# nltk                          3.8.1
# notebook                      6.4.8
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.23.1
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# opencv-contrib-python         4.7.0.72
# opencv-python                 4.7.0.72
# opencv-python-headless        4.7.0.72
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# optax                         0.1.5
# orbax-checkpoint              0.2.1
# osqp                          0.6.2.post8
# packaging                     23.1
# palettable                    3.3.3
# pandas                        1.5.3
# pandas-datareader             0.10.0
# pandas-gbq                    0.17.9
# pandocfilters                 1.5.0
# panel                         0.14.4
# param                         1.13.0
# parso                         0.8.3
# partd                         1.4.0
# pathlib                       1.0.1
# pathy                         0.10.1
# patsy                         0.5.3
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.4.0
# pip                           23.1.2
# pip-tools                     6.13.0
# platformdirs                  3.3.0
# plotly                        5.13.1
# plotnine                      0.10.1
# pluggy                        1.0.0
# polars                        0.17.3
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.3
# preshed                       3.0.8
# prettytable                   0.7.2
# proglog                       0.1.10
# progressbar2                  4.2.0
# prometheus-client             0.16.0
# promise                       2.3
# prompt-toolkit                3.0.38
# prophet                       1.1.2
# proto-plus                    1.22.2
# protobuf                      3.20.3
# psutil                        5.9.5
# psycopg2                      2.9.6
# ptyprocess                    0.7.0
# py-cpuinfo                    9.0.0
# py4j                          0.10.9.7
# pyarrow                       9.0.0
# pyasn1                        0.5.0
# pyasn1-modules                0.3.0
# pycocotools                   2.0.6
# pycparser                     2.21
# pyct                          0.5.0
# pydantic                      1.10.7
# pydata-google-auth            1.7.0
# pydot                         1.4.2
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyerfa                        2.0.0.3
# pygame                        2.3.0
# Pygments                      2.14.0
# PyGObject                     3.36.0
# pymc                          5.1.2
# PyMeeus                       0.5.12
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyproject_hooks               1.0.0
# pyrsistent                    0.19.3
# PySocks                       1.7.1
# pytensor                      2.10.1
# pytest                        7.2.2
# python-apt                    0.0.0
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                8.0.1
# python-utils                  3.5.2
# pytz                          2022.7.1
# pytz-deprecation-shim         0.1.0.post0
# pyviz-comms                   2.2.1
# PyWavelets                    1.4.1
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.7
# qudida                        0.0.4
# regex                         2022.10.31
# requests                      2.27.1
# requests-oauthlib             1.3.1
# requests-unixsocket           0.2.0
# requirements-parser           0.5.0
# rich                          13.3.4
# rpy2                          3.5.5
# rsa                           4.9
# scikit-image                  0.19.3
# scikit-learn                  1.2.2
# scipy                         1.10.1
# scs                           3.2.3
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# sentry-sdk                    1.23.1
# setuptools                    67.7.2
# shapely                       2.0.1
# six                           1.16.0
# sklearn-pandas                2.2.0
# smart-open                    6.3.0
# smmap                         5.0.0
# sniffio                       1.3.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soundfile                     0.12.1
# soupsieve                     2.4.1
# soxr                          0.3.5
# spacy                         3.5.2
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.4
# Sphinx                        3.5.4
# sphinxcontrib-applehelp       1.0.4
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.1
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# SQLAlchemy                    2.0.10
# sqlparse                      0.4.4
# srsly                         2.4.6
# statsmodels                   0.13.5
# sympy                         1.11.1
# tables                        3.8.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.12.2
# tensorboard-data-server       0.7.0
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.12.0
# tensorflow-datasets           4.9.2
# tensorflow-estimator          2.12.0
# tensorflow-gcs-config         2.12.0
# tensorflow-hub                0.13.0
# tensorflow-io-gcs-filesystem  0.32.0
# tensorflow-metadata           1.13.1
# tensorflow-probability        0.20.0
# tensorstore                   0.1.36
# termcolor                     2.3.0
# terminado                     0.17.1
# text-unidecode                1.3
# textblob                      0.17.1
# tf-slim                       1.1.0
# thinc                         8.1.9
# thop                          0.1.1.post2209072238
# threadpoolctl                 3.1.0
# tifffile                      2023.4.12
# tinycss2                      1.2.1
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         2.0.1+cu118
# torchaudio                    2.0.2+cu118
# torchdata                     0.6.1
# torchsummary                  1.5.1
# torchtext                     0.15.2
# torchvision                   0.15.2+cu118
# tornado                       6.3.1
# tqdm                          4.65.0
# traitlets                     5.7.1
# triton                        2.0.0
# tweepy                        4.13.0
# typer                         0.7.0
# types-setuptools              67.7.0.2
# typing_extensions             4.5.0
# tzdata                        2023.3
# tzlocal                       4.3
# ultralytics                   8.0.98
# uritemplate                   4.1.1
# urllib3                       1.26.15
# vega-datasets                 0.9.0
# wasabi                        1.1.1
# wcwidth                       0.2.6
# webcolors                     1.13
# webencodings                  0.5.1
# websocket-client              1.5.1
# Werkzeug                      2.3.0
# wheel                         0.40.0
# widgetsnbextension            3.6.4
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        2022.12.0
# xarray-einstats               0.5.1
# xgboost                       1.7.5
# xlrd                          2.0.1
# yellowbrick                   1.5
# yfinance                      0.2.18
# zict                          3.0.0
# zipp                          3.15.0

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# https://stackoverflow.com/questions/57377185/how-play-mp4-video-in-google-colab
#
# Compress the video file to a format supported by Google Colab (mpeg4 (native) -> h264 (libx264))

# %%
# !ffmpeg -i /content/yolov8_tracking/runs/track/exp/out.mp4 -vf fps=30 -vcodec libx264 output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/yolov8_tracking/runs/track/exp/out.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:01.00, start: 0.000000, bitrate: 3935 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 960x540 [SAR 1:1 DAR 16:9], 3927 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# File 'output.mp4' already exists. Overwrite ? [y/N] y
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e47d7a3600] using SAR=1/1
# [libx264 @ 0x55e47d7a3600] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e47d7a3600] profile High, level 3.1
# [libx264 @ 0x55e47d7a3600] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 960x540 [SAR 1:1 DAR 16:9], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   30 fps=0.0 q=-1.0 Lsize=     218kB time=00:00:00.90 bitrate=1979.7kbits/s speed=1.15x
# video:216kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.471381%
# [libx264 @ 0x55e47d7a3600] frame I:1     Avg QP:22.24  size: 55149
# [libx264 @ 0x55e47d7a3600] frame P:23    Avg QP:23.94  size:  6430
# [libx264 @ 0x55e47d7a3600] frame B:6     Avg QP:27.16  size:  2993
# [libx264 @ 0x55e47d7a3600] consecutive B-frames: 70.0%  0.0% 30.0%  0.0%
# [libx264 @ 0x55e47d7a3600] mb I  I16..4: 13.4% 77.9%  8.6%
# [libx264 @ 0x55e47d7a3600] mb P  I16..4:  2.3%  5.5%  0.9%  P16..4: 16.7%  6.6%  3.7%  0.0%  0.0%    skip:64.4%
# [libx264 @ 0x55e47d7a3600] mb B  I16..4:  1.1%  3.6%  0.2%  B16..8: 24.4%  4.3%  0.7%  direct: 1.3%  skip:64.4%  L0:54.5% L1:38.4% BI: 7.2%
# [libx264 @ 0x55e47d7a3600] 8x8 transform intra:68.5% inter:78.1%
# [libx264 @ 0x55e47d7a3600] coded y,uvDC,uvAC intra: 54.1% 58.6% 21.8% inter: 7.4% 12.2% 7.1%
# [libx264 @ 0x55e47d7a3600] i16 v,h,dc,p: 37% 37% 24%  1%
# [libx264 @ 0x55e47d7a3600] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 23% 38%  4%  2%  2%  1%  3%  5%
# [libx264 @ 0x55e47d7a3600] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 25% 12%  3%  4%  5%  3%  4%  4%
# [libx264 @ 0x55e47d7a3600] i8c dc,h,v,p: 37% 32% 29%  2%
# [libx264 @ 0x55e47d7a3600] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e47d7a3600] ref P L0: 68.7% 11.1% 13.8%  6.4%
# [libx264 @ 0x55e47d7a3600] ref B L0: 78.1% 18.0%  3.8%
# [libx264 @ 0x55e47d7a3600] kb/s:1768.00

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# # Evaluate

# %%
# !python val.py --tracking-method deepocsort --yolo-model weights/yolov8n.pt --benchmark MOT17-mini --imgsz 320
# Out:
# y
# /content/yolov8_tracking
# val: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, name=exp, project=runs/val, exists_ok=False, benchmark=MOT17-mini, split=train, eval_existing=, conf=0.45, imgsz=[320], device=[''], processes_per_device=2
# Eval repo already downloaded
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, source=assets/MOT17-mini/train/MOT17-05-FRCNN/MOT17-05-FRCNN, imgsz=[320], conf=0.45, device=, show=False, save=True, classes=[0], project=runs/val, name=exp3, exists_ok=True, half=False, vid_stride=1
# weights/yolov8n.pt
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, source=assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN, imgsz=[320], conf=0.45, device=, show=False, save=True, classes=[0], project=runs/val, name=exp3, exists_ok=True, half=False, vid_stride=1
# weights/yolov8n.pt
# Successfully loaded pretrained weights from "/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# Successfully loaded pretrained weights from "/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# image 1/6 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-05-FRCNN/MOT17-05-FRCNN/000001.jpg: 256x320 2 persons, 100.1ms
# image 2/6 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-05-FRCNN/MOT17-05-FRCNN/000002.jpg: 256x320 2 persons, 73.6ms
# image 1/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000001.jpg: 192x320 4 persons, 72.9ms
# image 3/6 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-05-FRCNN/MOT17-05-FRCNN/000003.jpg: 256x320 3 persons, 112.1ms
# image 2/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000002.jpg: 192x320 4 persons, 75.5ms
# image 4/6 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-05-FRCNN/MOT17-05-FRCNN/000004.jpg: 256x320 3 persons, 122.4ms
# image 3/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000003.jpg: 192x320 4 persons, 58.2ms
# image 5/6 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-05-FRCNN/MOT17-05-FRCNN/000005.jpg: 256x320 2 persons, 97.6ms
# image 4/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000004.jpg: 192x320 3 persons, 146.6ms
# image 6/6 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-05-FRCNN/MOT17-05-FRCNN/000006.jpg: 256x320 4 persons, 204.4ms
# Speed: 2.2ms preprocess, 118.4ms inference, 2.4ms postprocess, 1458.5ms tracking per image at shape (1, 3, 320, 320)
# Results saved to runs/val/exp3
# 8 labels saved to runs/val/exp3/labels
# image 5/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000005.jpg: 192x320 5 persons, 152.1ms
# image 6/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000006.jpg: 192x320 3 persons, 50.8ms
# image 7/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000007.jpg: 192x320 4 persons, 44.4ms
# image 8/8 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-04-FRCNN/MOT17-04-FRCNN/000008.jpg: 192x320 4 persons, 44.6ms
# Speed: 1.9ms preprocess, 80.6ms inference, 4.5ms postprocess, 1735.9ms tracking per image at shape (1, 3, 320, 320)
# Results saved to runs/val/exp3
# 10 labels saved to runs/val/exp3/labels
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, source=assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN, imgsz=[320], conf=0.45, device=, show=False, save=True, classes=[0], project=runs/val, name=exp3, exists_ok=True, half=False, vid_stride=1
# weights/yolov8n.pt
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, source=assets/MOT17-mini/train/MOT17-02-FRCNN/MOT17-02-FRCNN, imgsz=[320], conf=0.45, device=, show=False, save=True, classes=[0], project=runs/val, name=exp3, exists_ok=True, half=False, vid_stride=1
# weights/yolov8n.pt
# Successfully loaded pretrained weights from "/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# Successfully loaded pretrained weights from "/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# image 1/7 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN/000001.jpg: 192x320 3 persons, 78.5ms
# image 1/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-02-FRCNN/MOT17-02-FRCNN/000001.jpg: 192x320 4 persons, 103.6ms
# image 2/7 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN/000002.jpg: 192x320 3 persons, 55.8ms
# image 2/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-02-FRCNN/MOT17-02-FRCNN/000002.jpg: 192x320 4 persons, 58.0ms
# image 3/7 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN/000003.jpg: 192x320 4 persons, 75.6ms
# image 3/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-02-FRCNN/MOT17-02-FRCNN/000003.jpg: 192x320 4 persons, 150.3ms
# image 4/7 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN/000004.jpg: 192x320 3 persons, 111.7ms
# image 4/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-02-FRCNN/MOT17-02-FRCNN/000004.jpg: 192x320 4 persons, 56.4ms
# Speed: 2.8ms preprocess, 92.1ms inference, 3.2ms postprocess, 2234.6ms tracking per image at shape (1, 3, 320, 320)
# Results saved to runs/val/exp3
# 12 labels saved to runs/val/exp3/labels
# image 5/7 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN/000005.jpg: 192x320 4 persons, 58.2ms
# image 6/7 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN/000006.jpg: 192x320 5 persons, 71.9ms
# image 7/7 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-11-FRCNN/MOT17-11-FRCNN/000007.jpg: 192x320 5 persons, 68.7ms
# Speed: 1.6ms preprocess, 74.3ms inference, 3.1ms postprocess, 1945.8ms tracking per image at shape (1, 3, 320, 320)
# Results saved to runs/val/exp3
# 12 labels saved to runs/val/exp3/labels
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, source=assets/MOT17-mini/train/MOT17-09-FRCNN/MOT17-09-FRCNN, imgsz=[320], conf=0.45, device=, show=False, save=True, classes=[0], project=runs/val, name=exp3, exists_ok=True, half=False, vid_stride=1
# weights/yolov8n.pt
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, source=assets/MOT17-mini/train/MOT17-13-FRCNN/MOT17-13-FRCNN, imgsz=[320], conf=0.45, device=, show=False, save=True, classes=[0], project=runs/val, name=exp3, exists_ok=True, half=False, vid_stride=1
# weights/yolov8n.pt
# Successfully loaded pretrained weights from "/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# image 1/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-09-FRCNN/MOT17-09-FRCNN/000001.jpg: 192x320 2 persons, 78.7ms
# image 2/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-09-FRCNN/MOT17-09-FRCNN/000002.jpg: 192x320 2 persons, 70.7ms
# image 3/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-09-FRCNN/MOT17-09-FRCNN/000003.jpg: 192x320 1 person, 68.9ms
# image 4/4 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-09-FRCNN/MOT17-09-FRCNN/000004.jpg: 192x320 2 persons, 72.0ms
# Speed: 1.6ms preprocess, 72.6ms inference, 2.0ms postprocess, 857.8ms tracking per image at shape (1, 3, 320, 320)
# Results saved to runs/val/exp3
# 13 labels saved to runs/val/exp3/labels
# Successfully loaded pretrained weights from "/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# image 1/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-13-FRCNN/MOT17-13-FRCNN/000001.jpg: 192x320 1 person, 79.0ms
# image 2/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-13-FRCNN/MOT17-13-FRCNN/000002.jpg: 192x320 (no detections), 70.8ms
# image 3/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-13-FRCNN/MOT17-13-FRCNN/000003.jpg: 192x320 (no detections), 65.6ms
# image 4/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-13-FRCNN/MOT17-13-FRCNN/000004.jpg: 192x320 (no detections), 95.9ms
# image 5/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-13-FRCNN/MOT17-13-FRCNN/000005.jpg: 192x320 (no detections), 103.1ms
# Speed: 1.9ms preprocess, 82.9ms inference, 1.5ms postprocess, 184.1ms tracking per image at shape (1, 3, 320, 320)
# Results saved to runs/val/exp3
# 14 labels saved to runs/val/exp3/labels
# /content/yolov8_tracking
# track: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, source=assets/MOT17-mini/train/MOT17-10-FRCNN/MOT17-10-FRCNN, imgsz=[320], conf=0.45, device=, show=False, save=True, classes=[0], project=runs/val, name=exp3, exists_ok=True, half=False, vid_stride=1
# weights/yolov8n.pt
# Successfully loaded pretrained weights from "/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# image 1/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-10-FRCNN/MOT17-10-FRCNN/000001.jpg: 192x320 3 persons, 57.0ms
# image 2/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-10-FRCNN/MOT17-10-FRCNN/000002.jpg: 192x320 2 persons, 43.4ms
# image 3/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-10-FRCNN/MOT17-10-FRCNN/000003.jpg: 192x320 3 persons, 45.7ms
# image 4/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-10-FRCNN/MOT17-10-FRCNN/000004.jpg: 192x320 5 persons, 47.8ms
# image 5/5 /content/yolov8_tracking/assets/MOT17-mini/train/MOT17-10-FRCNN/MOT17-10-FRCNN/000005.jpg: 192x320 5 persons, 77.1ms
# Speed: 1.4ms preprocess, 54.2ms inference, 1.5ms postprocess, 1410.3ms tracking per image at shape (1, 3, 320, 320)
# Results saved to runs/val/exp3
# 15 labels saved to runs/val/exp3/labels
# val: yolo_model=weights/yolov8n.pt, reid_model=/content/yolov8_tracking/weights/mobilenetv2_x1_4_dukemtmcreid.pt, tracking_method=deepocsort, name=exp, project=runs/val, exists_ok=False, benchmark=MOT17-mini, split=train, eval_existing=, conf=0.45, imgsz=[320], device=[''], processes_per_device=2
#
# Eval Config:
# USE_PARALLEL         : True
# NUM_PARALLEL_CORES   : 4
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : /content/yolov8_tracking/val_utils/error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : False
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# MotChallenge2DBox Config:
# PRINT_CONFIG         : True
# GT_FOLDER            : assets/MOT17-mini/train
# TRACKERS_FOLDER      : runs/val/exp3
# OUTPUT_FOLDER        : None
# TRACKERS_TO_EVAL     : ['labels']
# CLASSES_TO_EVAL      : ['pedestrian']
# BENCHMARK            :
# SPLIT_TO_EVAL        : train
# INPUT_AS_ZIP         : False
# DO_PREPROC           : True
# TRACKER_SUB_FOLDER   :
# OUTPUT_SUB_FOLDER    :
# TRACKER_DISPLAY_NAMES : None
# SEQMAP_FOLDER        : None
# SEQMAP_FILE          : None
# SEQ_INFO             : {'MOT17-04-FRCNN': None, 'MOT17-05-FRCNN': None, 'MOT17-02-FRCNN': None, 'MOT17-11-FRCNN': None, 'MOT17-09-FRCNN': None, 'MOT17-13-FRCNN': None, 'MOT17-10-FRCNN': None}
# GT_LOC_FORMAT        : {gt_folder}/{seq}/gt/gt.txt
# SKIP_SPLIT_FOL       : True
#
# CLEAR Config:
# METRICS              : ['HOTA', 'CLEAR', 'Identity']
# THRESHOLD            : 0.5
# PRINT_CONFIG         : True
#
# Identity Config:
# METRICS              : ['HOTA', 'CLEAR', 'Identity']
# THRESHOLD            : 0.5
# PRINT_CONFIG         : True
#
# Evaluating 1 tracker(s) on 7 sequence(s) for 1 class(es) on MotChallenge2DBox dataset using the following metrics: HOTA, CLEAR, Identity, Count
#
#
# Evaluating labels
#
#
# All sequences for labels finished in 0.98 seconds
#
# HOTA: labels-pedestrian            HOTA      DetA      AssA      DetRe     DetPr     AssRe     AssPr     LocA      OWTA      HOTA(0)   LocA(0)   HOTALocA(0)
# MOT17-02-FRCNN                     35.654    14.659    87.699    14.833    81.579    89.712    89.712    82.729    35.912    42.64     79.51     33.903
# MOT17-04-FRCNN                     24.632    7.3957    83.81     7.4561    80.815    84.694    92.582    83.344    24.755    28.413    78.819    22.395
# MOT17-05-FRCNN                     43.46     27.759    68.55     28.421    79.934    71.687    85.223    82.556    44.051    54.433    78.693    42.835
# MOT17-09-FRCNN                     28.472    12.811    65.896    14.035    48.12     66.729    85.307    78.038    29.996    51.031    47.767    24.376
# MOT17-10-FRCNN                     29.834    14.204    62.878    14.349    75.731    65.121    79.599    79.23     30.002    39.47     74.663    29.47
# MOT17-11-FRCNN                     36.254    17.905    73.773    18.178    80.117    75.934    85.27     82.364    36.561    44.775    78.84     35.301
# MOT17-13-FRCNN                     4.6772    0.63945   34.211    0.63945   68.421    34.211    68.421    77.564    4.6772    6.8359    67.209    4.5943
# COMBINED                           28.797    10.929    77.209    11.082    77.768    79.159    88.633    81.727    29.034    35.375    76.283    26.985
#
# CLEAR: labels-pedestrian           MOTA      MOTP      MODA      CLR_Re    CLR_Pr    MTR       PTR       MLR       sMOTA     CLR_TP    CLR_FN    CLR_FP    IDSW      MT        PT        ML        Frag
# MOT17-02-FRCNN                     18.182    79.51     18.182    18.182    100       18.182    0         81.818    14.456    16        72        0         0         4         0         18        0
# MOT17-04-FRCNN                     6.8452    83.89     6.8452    8.0357    87.097    7.1429    2.381     90.476    5.5507    27        309       4         0         3         1         38        1
# MOT17-05-FRCNN                     33.333    78.693    35.556    35.556    100       22.222    22.222    55.556    25.758    16        29        0         1         2         2         5         1
# MOT17-09-FRCNN                     -4.1667   83.348    -4.1667   12.5      42.857    0         16.667    83.333    -6.2481   3         21        4         0         0         1         5         1
# MOT17-10-FRCNN                     18.947    74.663    18.947    18.947    100       10.526    15.789    73.684    14.147    18        77        0         0         2         3         14        1
# MOT17-11-FRCNN                     22.689    78.84     22.689    22.689    100       17.647    11.765    70.588    17.888    27        92        0         0         3         2         12        1
# MOT17-13-FRCNN                     0.93458   67.209    0.93458   0.93458   100       0         4.5455    95.455    0.62812   1         106       0         0         0         1         21        0
# COMBINED                           12.162    79.501    12.285    13.268    93.103    10.219    7.2993    82.482    9.4425    108       706       8         1         14        10        113       5
#
# Identity: labels-pedestrian        IDF1      IDR       IDP       IDTP      IDFN      IDFP
# MOT17-02-FRCNN                     30.769    18.182    100       16        72        0
# MOT17-04-FRCNN                     14.714    8.0357    87.097    27        309       4
# MOT17-05-FRCNN                     49.18     33.333    93.75     15        30        1
# MOT17-09-FRCNN                     19.355    12.5      42.857    3         21        4
# MOT17-10-FRCNN                     31.858    18.947    100       18        77        0
# MOT17-11-FRCNN                     36.986    22.689    100       27        92        0
# MOT17-13-FRCNN                     1.8519    0.93458   100       1         106       0
# COMBINED                           23.011    13.145    92.241    107       707       9
#
# Count: labels-pedestrian           Dets      GT_Dets   IDs       GT_IDs
# MOT17-02-FRCNN                     16        88        4         22
# MOT17-04-FRCNN                     31        336       5         42
# MOT17-05-FRCNN                     16        45        5         9
# MOT17-09-FRCNN                     7         24        2         6
# MOT17-10-FRCNN                     18        95        5         19
# MOT17-11-FRCNN                     27        119       5         17
# MOT17-13-FRCNN                     1         107       1         22
# COMBINED                           116       814       27        137
